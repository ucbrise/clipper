# %%
import sys
import json
import os
import requests
import random
from datetime import datetime
import time

import pandas as pd
import numpy as np
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Run a serving workload

# %%
def load_digits(digits_location, digits_filename = "train.data", norm=True):
    digits_path = digits_location + "/" + digits_filename
    print("Source file: %s" % digits_path)
    df = pd.read_csv(digits_path, sep=",", header=None)
    data = df.values
    print("Number of image files: %d" % len(data))
    y = data[:,0]
    X = data[:,1:]
    Z = X
    if norm:
        mu = np.mean(X,0)
        sigma = np.var(X,0)
        Z = (X - mu) / np.array([np.sqrt(z) if z > 0 else 1. for z in sigma])
    return Z, y

def filter_data(data):
    cx, cy = data
    binary_x = []
    binary_y = []
    for i in range(len(cy)):
        if cy[i] == 3:
            binary_x.append(cx[i,:])
            binary_y.append(1.0)
        elif cy[i] == 6:
            binary_x.append(cx[i,:])
            binary_y.append(0.0)
    return np.array(binary_x), np.array(binary_y)
            

def mnist_update(host, uid, x, y):
    url = "http://%s:1337/update" % host
    req_json = json.dumps({'uid': uid, 'input': list(x), 'label': y})
    headers = {'Content-type': 'application/json'}
    start = datetime.now()
    r = requests.post(url, headers=headers, data=req_json)
    end = datetime.now()
    latency = (end - start).total_seconds() * 1000.0
    print("'%s', %f ms" % (r.text, latency))

def mnist_prediction(host, uid, x):
    url = "http://%s:1337/predict" % host
    req_json = json.dumps({'uid': uid, 'input': list(x)})
    headers = {'Content-type': 'application/json'}
    # x_str = ", ".join(["%d" % a for a in x])
    start = datetime.now()
    r = requests.post(url, headers=headers, data=req_json)
    end = datetime.now()
    latency = (end - start).total_seconds() * 1000.0
    pred = float(r.text.split(":")[1].strip())
    return (pred, latency)



def send_updates(num_updates):
    uid = 0
    for i in range(num_updates):
        example_num = np.random.randint(0, len(test_y))
        mnist_update(host, uid, test_x[example_num], float(test_y[example_num]))

def run_iteration(uid):
    correct = 0
    false_pos = 0
    false_neg = 0
    latencies = []
    true_pos = 0
    true_neg = 0
    total = 100
    for i in range(total):
        example_num = np.random.randint(0, len(test_y))
        correct_y = float(test_y[example_num])
        pred_y, latency = mnist_prediction(host, uid, test_x[example_num])
        if correct_y == pred_y:
            if correct_y == 0:
                true_neg += 1
            elif correct_y == 1:
                true_pos += 1
            correct += 1
        elif correct_y == 0 and pred_y == 1:
            false_pos += 1
        elif correct_y == 1 and pred_y == 0:
            false_neg += 1
        else:
            print "predicted: {p}, correct: {c}".format(p=pred_y, c=correct_y)
        latencies.append(latency)
    total = float(total)    
    return (float(correct)/total,
            float(false_pos)/total,
            float(false_neg)/total,
            float(true_pos)/total,
            float(true_neg)/total,
            np.mean(latencies))

def run_serving_workload():
    fig, (ax_acc, ax_lat) = plt.subplots(2,1, sharex=True)
    ax_acc.set_ylabel("accuracy")
    ax_lat.set_xlabel("iterations")
    ax_lat.set_ylabel("latency")
    ax_acc.set_ylim(0, 1.0)
    xs = []
    accs = []
    lats = []
    j = 0
    uid = 0
    while True:
        correct, fp, fn, tp, tn, mean_lat, = run_iteration(uid)
        xs.append(j)
        accs.append(correct)
        lats.append(mean_lat)
        j += 1
        ax_acc.set_xlim(0, j + 1)
        ax_lat.set_xlim(0, j + 1)
        
        ax_acc.plot(xs, accs, 'b')
        ax_lat.plot(xs, lats, 'r')
        ax_lat.set_ylim(0, 150)
        fig.canvas.draw()
        print "Accuracy: {cor}, false positives: {fp}, false negatives: {fn}, true positives: {tp}, true negatives: {tn}".format(
            cor=correct, fp=fp, fn=fn, tp=tp, tn=tn)
        print "Mean latency: {lat} ms".format(lat = mean_lat)

# %%
test_x, test_y = filter_data(load_digits(os.path.expanduser("~/model-serving/data/mnist_data"), digits_filename="test.data"))
host = "ec2-52-53-151-0.us-west-1.compute.amazonaws.com"
# Out:
# Source file: /Users/crankshaw/model-serving/data/mnist_data/test.data
# Number of image files: 10000

# %%
# send_updates(200)
run_serving_workload()
# Out:
# <img src="data:image/png;base64,...">
# Accuracy: 0.44, false positives: 0.0, false negatives: 0.56, true positives: 0.0, true negatives: 0.44
# Mean latency: 55.33431 ms
# Accuracy: 0.48, false positives: 0.0, false negatives: 0.52, true positives: 0.0, true negatives: 0.48
# Mean latency: 66.58096 ms
# Accuracy: 0.38, false positives: 0.0, false negatives: 0.62, true positives: 0.0, true negatives: 0.38
# Mean latency: 56.63465 ms
# Accuracy: 0.49, false positives: 0.0, false negatives: 0.51, true positives: 0.0, true negatives: 0.49
# Mean latency: 53.52824 ms
# Accuracy: 0.43, false positives: 0.0, false negatives: 0.57, true positives: 0.0, true negatives: 0.43
# Mean latency: 53.32909 ms
# Accuracy: 0.42, false positives: 0.0, false negatives: 0.58, true positives: 0.0, true negatives: 0.42
# Mean latency: 56.68555 ms
# Accuracy: 0.47, false positives: 0.0, false negatives: 0.53, true positives: 0.0, true negatives: 0.47
# Mean latency: 53.95812 ms
# Accuracy: 0.46, false positives: 0.0, false negatives: 0.54, true positives: 0.0, true negatives: 0.46
# Mean latency: 55.24884 ms
# Accuracy: 0.45, false positives: 0.0, false negatives: 0.55, true positives: 0.0, true negatives: 0.45
# Mean latency: 65.66102 ms
# Accuracy: 0.41, false positives: 0.0, false negatives: 0.59, true positives: 0.0, true negatives: 0.41
# Mean latency: 64.53876 ms
# Accuracy: 0.54, false positives: 0.01, false negatives: 0.45, true positives: 0.05, true negatives: 0.49
# Mean latency: 63.66978 ms
# Accuracy: 0.81, false positives: 0.06, false negatives: 0.13, true positives: 0.46, true negatives: 0.35
# Mean latency: 63.87703 ms
# Accuracy: 0.81, false positives: 0.08, false negatives: 0.11, true positives: 0.4, true negatives: 0.41
# Mean latency: 88.96146 ms
# Accuracy: 0.79, false positives: 0.14, false negatives: 0.07, true positives: 0.53, true negatives: 0.26
# Mean latency: 69.78337 ms
# Accuracy: 0.86, false positives: 0.04, false negatives: 0.1, true positives: 0.43, true negatives: 0.43
# Mean latency: 93.28343 ms
# Accuracy: 0.78, false positives: 0.04, false negatives: 0.18, true positives: 0.43, true negatives: 0.35
# Mean latency: 73.89391 ms
# Accuracy: 0.84, false positives: 0.09, false negatives: 0.07, true positives: 0.47, true negatives: 0.37
# Mean latency: 88.20165 ms
# Accuracy: 0.94, false positives: 0.04, false negatives: 0.02, true positives: 0.63, true negatives: 0.31
# Mean latency: 83.19647 ms
# Accuracy: 0.91, false positives: 0.09, false negatives: 0.0, true positives: 0.57, true negatives: 0.34
# Mean latency: 111.30041 ms
# Accuracy: 0.89, false positives: 0.1, false negatives: 0.01, true positives: 0.56, true negatives: 0.33
# Mean latency: 75.16168 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.52, true negatives: 0.45
# Mean latency: 76.48471 ms
# Accuracy: 0.87, false positives: 0.13, false negatives: 0.0, true positives: 0.58, true negatives: 0.29
# Mean latency: 77.13872 ms
# Accuracy: 0.84, false positives: 0.15, false negatives: 0.01, true positives: 0.56, true negatives: 0.28
# Mean latency: 68.99246 ms
# Accuracy: 0.92, false positives: 0.06, false negatives: 0.02, true positives: 0.62, true negatives: 0.3
# Mean latency: 52.16036 ms
# Accuracy: 0.91, false positives: 0.09, false negatives: 0.0, true positives: 0.52, true negatives: 0.39
# Mean latency: 66.76905 ms
# Accuracy: 0.9, false positives: 0.09, false negatives: 0.01, true positives: 0.52, true negatives: 0.38
# Mean latency: 85.04531 ms
# Accuracy: 0.93, false positives: 0.07, false negatives: 0.0, true positives: 0.64, true negatives: 0.29
# Mean latency: 63.17769 ms
# Accuracy: 0.84, false positives: 0.16, false negatives: 0.0, true positives: 0.53, true negatives: 0.31
# Mean latency: 61.18435 ms
# Accuracy: 0.87, false positives: 0.13, false negatives: 0.0, true positives: 0.53, true negatives: 0.34
# Mean latency: 58.14826 ms
# Accuracy: 0.93, false positives: 0.07, false negatives: 0.0, true positives: 0.51, true negatives: 0.42
# Mean latency: 64.13862 ms
# Accuracy: 0.92, false positives: 0.08, false negatives: 0.0, true positives: 0.51, true negatives: 0.41
# Mean latency: 57.56536 ms
# Accuracy: 0.91, false positives: 0.09, false negatives: 0.0, true positives: 0.48, true negatives: 0.43
# Mean latency: 66.65063 ms
# Accuracy: 0.87, false positives: 0.13, false negatives: 0.0, true positives: 0.59, true negatives: 0.28
# Mean latency: 56.27551 ms
# Accuracy: 0.9, false positives: 0.1, false negatives: 0.0, true positives: 0.58, true negatives: 0.32
# Mean latency: 54.92934 ms
# Accuracy: 0.9, false positives: 0.1, false negatives: 0.0, true positives: 0.47, true negatives: 0.43
# Mean latency: 56.86295 ms
# Accuracy: 0.92, false positives: 0.08, false negatives: 0.0, true positives: 0.44, true negatives: 0.48
# Mean latency: 58.06157 ms
# Accuracy: 0.94, false positives: 0.06, false negatives: 0.0, true positives: 0.54, true negatives: 0.4
# Mean latency: 52.09519 ms
# Accuracy: 0.88, false positives: 0.12, false negatives: 0.0, true positives: 0.56, true negatives: 0.32
# Mean latency: 54.19094 ms
# Accuracy: 0.9, false positives: 0.1, false negatives: 0.0, true positives: 0.41, true negatives: 0.49
# Mean latency: 52.03452 ms
# Accuracy: 0.94, false positives: 0.06, false negatives: 0.0, true positives: 0.57, true negatives: 0.37
# Mean latency: 56.93802 ms
# Accuracy: 0.92, false positives: 0.08, false negatives: 0.0, true positives: 0.59, true negatives: 0.33
# Mean latency: 54.73491 ms
# Accuracy: 0.89, false positives: 0.11, false negatives: 0.0, true positives: 0.55, true negatives: 0.34
# Mean latency: 53.74091 ms
# Accuracy: 0.87, false positives: 0.13, false negatives: 0.0, true positives: 0.5, true negatives: 0.37
# Mean latency: 52.48497 ms
# Accuracy: 0.85, false positives: 0.15, false negatives: 0.0, true positives: 0.54, true negatives: 0.31
# Mean latency: 56.29361 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.58, true negatives: 0.41
# Mean latency: 54.10827 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.63, true negatives: 0.35
# Mean latency: 58.12287 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.51, true negatives: 0.47
# Mean latency: 56.61897 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.62, true negatives: 0.37
# Mean latency: 55.52444 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.53, true negatives: 0.47
# Mean latency: 54.14698 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.54, true negatives: 0.46
# Mean latency: 62.36772 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.58, true negatives: 0.41
# Mean latency: 56.8707 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.49, true negatives: 0.5
# Mean latency: 51.84933 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.59, true negatives: 0.41
# Mean latency: 55.75199 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.48, true negatives: 0.51
# Mean latency: 53.76712 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.52, true negatives: 0.44
# Mean latency: 56.76496 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.5, true negatives: 0.5
# Mean latency: 53.47358 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.45, true negatives: 0.53
# Mean latency: 53.39939 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.45, true negatives: 0.54
# Mean latency: 52.60553 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.57, true negatives: 0.41
# Mean latency: 55.27393 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.59, true negatives: 0.41
# Mean latency: 53.47096 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.57, true negatives: 0.42
# Mean latency: 56.18592 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.58, true negatives: 0.41
# Mean latency: 62.33003 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.48, true negatives: 0.48
# Mean latency: 53.06151 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.57, true negatives: 0.42
# Mean latency: 54.05712 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.55, true negatives: 0.44
# Mean latency: 53.67291 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.61, true negatives: 0.39
# Mean latency: 59.90875 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.49, true negatives: 0.49
# Mean latency: 59.09787 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.49, true negatives: 0.5
# Mean latency: 72.28449 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.61, true negatives: 0.38
# Mean latency: 87.21933 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.6, true negatives: 0.39
# Mean latency: 64.7782 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.45, true negatives: 0.52
# Mean latency: 81.79515 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.55, true negatives: 0.45
# Mean latency: 74.24839 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.67, true negatives: 0.31
# Mean latency: 56.19235 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.58, true negatives: 0.41
# Mean latency: 58.0754 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.53, true negatives: 0.45
# Mean latency: 52.10403 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.5, true negatives: 0.47
# Mean latency: 56.22732 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.52, true negatives: 0.46
# Mean latency: 53.57974 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.57, true negatives: 0.43
# Mean latency: 53.6662 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.5, true negatives: 0.49
# Mean latency: 55.93198 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.63, true negatives: 0.36
# Mean latency: 53.99434 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.49, true negatives: 0.5
# Mean latency: 52.99246 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.46, true negatives: 0.51
# Mean latency: 59.4847 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.48, true negatives: 0.5
# Mean latency: 54.57769 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.49, true negatives: 0.49
# Mean latency: 55.12168 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.62, true negatives: 0.38
# Mean latency: 56.74723 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.58, true negatives: 0.4
# Mean latency: 51.48069 ms
# Accuracy: 0.99, false positives: 0.0, false negatives: 0.01, true positives: 0.55, true negatives: 0.44
# Mean latency: 63.6727 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.53, true negatives: 0.46
# Mean latency: 59.16671 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.5, true negatives: 0.49
# Mean latency: 55.79989 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.51, true negatives: 0.48
# Mean latency: 55.38524 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.53, true negatives: 0.46
# Mean latency: 58.18927 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.45, true negatives: 0.55
# Mean latency: 54.37155 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.57, true negatives: 0.4
# Mean latency: 54.49877 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.56, true negatives: 0.4
# Mean latency: 54.96316 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.52, true negatives: 0.46
# Mean latency: 58.06219 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.51, true negatives: 0.47
# Mean latency: 60.15117 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.53, true negatives: 0.46
# Mean latency: 58.07529 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.49, true negatives: 0.51
# Mean latency: 55.34885 ms
# Accuracy: 0.98, false positives: 0.01, false negatives: 0.01, true positives: 0.48, true negatives: 0.5
# Mean latency: 54.18123 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.57, true negatives: 0.41
# Mean latency: 53.88208 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.53, true negatives: 0.45
# Mean latency: 54.60059 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.46, true negatives: 0.53
# Mean latency: 55.34758 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.56, true negatives: 0.44
# Mean latency: 66.12495 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.61, true negatives: 0.39
# Mean latency: 57.69717 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.46, true negatives: 0.52
# Mean latency: 60.08551 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.54, true negatives: 0.45
# Mean latency: 52.68419 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.48, true negatives: 0.51
# Mean latency: 69.26959 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.52, true negatives: 0.45
# Mean latency: 53.41777 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.49, true negatives: 0.48
# Mean latency: 57.00414 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.48, true negatives: 0.51
# Mean latency: 57.18088 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.61, true negatives: 0.36
# Mean latency: 52.96689 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.54, true negatives: 0.43
# Mean latency: 51.92601 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.6, true negatives: 0.38
# Mean latency: 52.7315 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.59, true negatives: 0.37
# Mean latency: 56.93743 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.59, true negatives: 0.4
# Mean latency: 57.7624 ms
# Accuracy: 0.96, false positives: 0.03, false negatives: 0.01, true positives: 0.54, true negatives: 0.42
# Mean latency: 56.44256 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.48, true negatives: 0.5
# Mean latency: 51.75565 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.58, true negatives: 0.42
# Mean latency: 50.89643 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.54, true negatives: 0.45
# Mean latency: 50.30427 ms
# Accuracy: 0.97, false positives: 0.02, false negatives: 0.01, true positives: 0.54, true negatives: 0.43
# Mean latency: 53.06295 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.49, true negatives: 0.5
# Mean latency: 51.29413 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.55, true negatives: 0.45
# Mean latency: 52.10191 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.43, true negatives: 0.55
# Mean latency: 54.28811 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.6, true negatives: 0.39
# Mean latency: 52.75718 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.61, true negatives: 0.37
# Mean latency: 57.20378 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.5, true negatives: 0.49
# Mean latency: 60.10197 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.57, true negatives: 0.4
# Mean latency: 53.08886 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.5, true negatives: 0.5
# Mean latency: 51.21351 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.52, true negatives: 0.44
# Mean latency: 51.17479 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.55, true negatives: 0.41
# Mean latency: 56.20962 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.55, true negatives: 0.44
# Mean latency: 77.99894 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.45, true negatives: 0.55
# Mean latency: 60.66622 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.61, true negatives: 0.39
# Mean latency: 60.06409 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.44, true negatives: 0.54
# Mean latency: 52.77282 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.55, true negatives: 0.43
# Mean latency: 64.54132 ms
# Accuracy: 0.95, false positives: 0.05, false negatives: 0.0, true positives: 0.57, true negatives: 0.38
# Mean latency: 62.99797 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.54, true negatives: 0.45
# Mean latency: 53.87075 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.44, true negatives: 0.54
# Mean latency: 56.41027 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.47, true negatives: 0.53
# Mean latency: 53.89494 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.56, true negatives: 0.42
# Mean latency: 55.28754 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.65, true negatives: 0.33
# Mean latency: 59.24807 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.6, true negatives: 0.39
# Mean latency: 53.97872 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.54, true negatives: 0.44
# Mean latency: 54.97063 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.6, true negatives: 0.38
# Mean latency: 51.48318 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.52, true negatives: 0.47
# Mean latency: 51.77923 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.57, true negatives: 0.41
# Mean latency: 51.05638 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.54, true negatives: 0.44
# Mean latency: 65.49117 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.47, true negatives: 0.52
# Mean latency: 61.12807 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.47, true negatives: 0.52
# Mean latency: 61.15392 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.62, true negatives: 0.34
# Mean latency: 59.70459 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.47, true negatives: 0.5
# Mean latency: 63.53982 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.46, true negatives: 0.53
# Mean latency: 63.29433 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.5, true negatives: 0.49
# Mean latency: 56.95406 ms
# Accuracy: 0.95, false positives: 0.04, false negatives: 0.01, true positives: 0.52, true negatives: 0.43
# Mean latency: 58.20511 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.48, true negatives: 0.51
# Mean latency: 56.85267 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.56, true negatives: 0.43
# Mean latency: 60.42708 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.51, true negatives: 0.49
# Mean latency: 67.4675 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.56, true negatives: 0.42
# Mean latency: 54.97489 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.52, true negatives: 0.47
# Mean latency: 61.15216 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.57, true negatives: 0.42
# Mean latency: 61.1299 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.53, true negatives: 0.47
# Mean latency: 72.15602 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.53, true negatives: 0.44
# Mean latency: 57.43972 ms
# Accuracy: 0.99, false positives: 0.0, false negatives: 0.01, true positives: 0.59, true negatives: 0.4
# Mean latency: 57.54408 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.5, true negatives: 0.47
# Mean latency: 57.66299 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.47, true negatives: 0.51
# Mean latency: 62.26956 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.57, true negatives: 0.43
# Mean latency: 57.17095 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.6, true negatives: 0.39
# Mean latency: 53.45121 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.49, true negatives: 0.51
# Mean latency: 59.64105 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.57, true negatives: 0.41
# Mean latency: 59.04038 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.56, true negatives: 0.4
# Mean latency: 62.8791 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.6, true negatives: 0.39
# Mean latency: 54.17411 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.59, true negatives: 0.39
# Mean latency: 55.21734 ms
# Accuracy: 0.95, false positives: 0.05, false negatives: 0.0, true positives: 0.5, true negatives: 0.45
# Mean latency: 57.59446 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.49, true negatives: 0.51
# Mean latency: 55.84816 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.49, true negatives: 0.48
# Mean latency: 61.20417 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.45, true negatives: 0.53
# Mean latency: 70.88962 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.48, true negatives: 0.5
# Mean latency: 56.64999 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.47, true negatives: 0.53
# Mean latency: 53.52459 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.55, true negatives: 0.43
# Mean latency: 59.73166 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.54, true negatives: 0.44
# Mean latency: 60.71673 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.51, true negatives: 0.46
# Mean latency: 55.93329 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.54, true negatives: 0.46
# Mean latency: 60.9934 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.61, true negatives: 0.38
# Mean latency: 56.83991 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.55, true negatives: 0.45
# Mean latency: 52.73479 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.63, true negatives: 0.33
# Mean latency: 66.22064 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.43, true negatives: 0.57
# Mean latency: 54.46729 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.44, true negatives: 0.52
# Mean latency: 52.12466 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.57, true negatives: 0.41
# Mean latency: 54.48156 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.49, true negatives: 0.5
# Mean latency: 55.40581 ms
# Accuracy: 0.96, false positives: 0.04, false negatives: 0.0, true positives: 0.59, true negatives: 0.37
# Mean latency: 72.11094 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.53, true negatives: 0.46
# Mean latency: 58.80764 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.53, true negatives: 0.44
# Mean latency: 54.5369 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.56, true negatives: 0.41
# Mean latency: 63.48675 ms
# Accuracy: 0.98, false positives: 0.02, false negatives: 0.0, true positives: 0.6, true negatives: 0.38
# Mean latency: 56.61719 ms
# Accuracy: 0.97, false positives: 0.03, false negatives: 0.0, true positives: 0.52, true negatives: 0.45
# Mean latency: 67.53684 ms
# Accuracy: 1.0, false positives: 0.0, false negatives: 0.0, true positives: 0.6, true negatives: 0.4
# Mean latency: 57.18278 ms
# Accuracy: 0.99, false positives: 0.01, false negatives: 0.0, true positives: 0.53, true negatives: 0.46
# Mean latency: 56.22583 ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-81fd866b386f> in <module>()
#       1 # send_updates(200)
# ----> 2 run_serving_workload()
#
# <ipython-input-2-1e08048a9550> in run_serving_workload()
#     103     uid = 0
#     104     while True:
# --> 105         correct, fp, fn, tp, tn, mean_lat, = run_iteration(uid)
#     106         xs.append(j)
#     107         accs.append(correct)
#
# <ipython-input-2-1e08048a9550> in run_iteration(uid)
#      69         example_num = np.random.randint(0, len(test_y))
#      70         correct_y = float(test_y[example_num])
# ---> 71         pred_y, latency = mnist_prediction(host, uid, test_x[example_num])
#      72         if correct_y == pred_y:
#      73             if correct_y == 0:
#
# <ipython-input-2-1e08048a9550> in mnist_prediction(host, uid, x)
#      44     # x_str = ", ".join(["%d" % a for a in x])
#      45     start = datetime.now()
# ---> 46     r = requests.post(url, headers=headers, data=req_json)
#      47     end = datetime.now()
#      48     latency = (end - start).total_seconds() * 1000.0
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/api.pyc in post(url, data, json, **kwargs)
#     109     """
#     110
# --> 111     return request('post', url, data=data, json=json, **kwargs)
#     112
#     113
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     401                     decode_content=False,
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#     405
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     576                                                   timeout=timeout_obj,
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#     580             # If we're going to release the connection in ``finally:``, then
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383         try:
#     384             try:  # Python 2.7, use buffering of HTTP responses
# --> 385                 httplib_response = conn.getresponse(buffering=True)
#     386             except TypeError:  # Python 2.6 and older
#     387                 httplib_response = conn.getresponse()
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /Users/crankshaw/anaconda2/envs/clipper/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
